# %%
# Lecture 47, notes by Akhona Njeje.
# Date 10 February 2023.
# Seaborn = Statistical plotting library.
# Works well with Pandas library.
# Consult documentation http://seaborn.pydata.org/ for other  tools.

import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()   # Total of people who had a meal & left a tip.
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Univariate.

sns.displot(tips['total_bill'], kde= False, bins = 30)   # Histogram.

# %%
sns.displot(tips['total_bill'])

# %%
# Joint plots.

sns.jointplot(x='total_bill',y='tip', data=tips)

# %%
sns.jointplot(x='total_bill',y='tip', data=tips, kind='reg')   # reg = regression line.

# %%
sns.jointplot(x='total_bill',y='tip', data=tips, kind='kde')

# %%
# Pair plot. nICE QUICK WAY TO ZOOM IN YOUR DATA.

sns.pairplot(tips, hue='sex')   # Hue lets us create a legend.

# %%
# Rug plots.

sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create dataset.
dataset = np.random.randn(25)

# Set up the x-axis for the plot.

x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# %%
# 100 equally spaced points from x_min to x_max.
url = 'http://en.wikipedia.org/wiki/kernel_density_estimarion#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    # Create a kernel for each point an append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    # Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey', alpha=0.5)
    
plt.ylim(0,1)   # Multi Gaussian plots.   # E.

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function.

sum_of_kde = np.sum(kernel_list, axis=0)

# Plot figure.

fig = plt.plot(x_axis, sum_of_kde, color = 'indianred')

# Add the initial rugplot

sns.rugplot(dataset, c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")    # E.

# %%
# Categorical Plots.

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator = np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# Boxplots.

sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Violin plots.

sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips, hue='sex')   # hue = legend.
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
